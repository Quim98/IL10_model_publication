# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import use
use('Agg')
import warnings
warnings.filterwarnings('ignore')
plt.rc('xtick', labelsize=14)
plt.rc('ytick', labelsize=14)
import seaborn as sns
from scipy.optimize import curve_fit
from src.simulate_func import hill_func

# %% [markdown]
# #### Simulations Monocytes/Tcells for STAT3/downstream signaling linear relation

# %%
# Colors for mutants:
color_sim = ["blue","darkgreen"]
color_invit = ["cornflowerblue","forestgreen"]
color_area = ["lightblue","lightgreeen"]
markers = ['o','^']
linestyles = ["dotted","dashdot"]

# %%
df_sim = pd.read_csv("results/raw_param/simulations_raw_MO_T.csv")
df_sim = df_sim.loc[(df_sim["Variant"].isin(["WT","vIL-10"]))&(df_sim["Cell_type"].isin(["T4.Mean","MO.Mean"]))]
fig,ax=plt.subplots(1,1,figsize=(9, 8), dpi=400)
for plot_num in df_sim["Plot"].drop_duplicates():
    df_sim_plot = df_sim.loc[df_sim["Plot"]==plot_num]
    max_WT = df_sim_plot.loc[df_sim_plot["Variant"]==variant]["Result"].max()
    # First plot WT
    variant = list(dict.fromkeys(df_sim_plot["Variant"]))[0]
    ax.plot(df_sim_plot.loc[df_sim_plot["Variant"]==variant]["IL0"].values, np.multiply(df_sim_plot.loc[df_sim_plot["Variant"]==variant]["Result"].values,100/(max_WT)), linewidth=7.5, label=variant+" "+df_sim_plot["Cell_type"].values[0], linestyle="dashed")
    i=0
    # Then plot the other variants
    for variant in list(dict.fromkeys(df_sim_plot["Variant"]))[1:]:
        ax.plot(df_sim_plot.loc[df_sim_plot["Variant"]==variant]["IL0"].values, np.multiply(df_sim_plot.loc[df_sim_plot["Variant"]==variant]["Result"].values,100/(max_WT)), linewidth=7.5, label=variant+" "+df_sim_plot["Cell_type"].values[0], linestyle=linestyles[i])
        i += 1
plt.legend(loc="upper left", fontsize=20)
plt.xscale('log')
ax.set_xticks(10**np.arange(round(np.log10(df_sim_plot["IL0"].min()),0)+1,round(np.log10(df_sim_plot["IL0"].max()),0)+1,2))
ax.spines["bottom"].set_linewidth(4)
ax.spines["left"].set_linewidth(4)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.xaxis.set_tick_params(width=5, length=10)
ax.yaxis.set_tick_params(width=5, length=10)
ax.tick_params(axis='x', labelsize=25)
ax.tick_params(axis='y', labelsize=25)
plt.title(cell, fontsize=25)
plt.ylabel(list(df_sim_plot["STAT_type"])[0], fontsize=25)
plt.xlabel('IL-10 (M)', fontsize=25)
plt.savefig('figures/raw_param/Plot_all_cell_variants_norm.png', transparent=True, bbox_inches="tight")
plt.show()

# %%
df_sim = pd.read_csv("results/raw_param/simulations_raw_MO_T.csv")
df_sim = df_sim.loc[(df_sim["Variant"].isin(["WT","vIL-10"]))&(df_sim["Cell_type"].isin(["T4.Mean","MO.Mean"]))]
df_sim.loc[df_sim["Result"] > df_sim.loc[df_sim["Cell_type"]=="T4.Mean","Result"].max(),"Result"] = df_sim.loc[df_sim["Cell_type"]=="T4.Mean","Result"].max()
fig,ax=plt.subplots(1,1,figsize=(9, 8), dpi=400)
for plot_num in df_sim["Plot"].drop_duplicates():
    df_sim_plot = df_sim.loc[df_sim["Plot"]==plot_num]
    # First plot WT
    variant = "WT"
    variant_list = df_sim_plot["Variant"].drop_duplicates().to_list()
    variant_list.remove("WT")
    ax.plot(df_sim_plot.loc[df_sim_plot["Variant"]==variant]["IL0"].values, df_sim_plot.loc[df_sim_plot["Variant"]==variant]["Result"].values, linewidth=7.5, label=variant+" "+df_sim_plot["Cell_type"].values[0], linestyle="dashed")
    i=0
    # Then plot the other variants
    for variant in variant_list:
        ax.plot(df_sim_plot.loc[df_sim_plot["Variant"]==variant]["IL0"].values, df_sim_plot.loc[df_sim_plot["Variant"]==variant]["Result"].values, linewidth=7.5, label=variant+" "+df_sim_plot["Cell_type"].values[0], linestyle=linestyles[i])
        i += 1
plt.legend(loc="upper left", fontsize=20)
plt.xscale('log')
ax.set_xticks(10**np.arange(round(np.log10(df_sim_plot["IL0"].min()),0)+1,round(np.log10(df_sim_plot["IL0"].max()),0)+1,2))
ax.spines["bottom"].set_linewidth(4)
ax.spines["left"].set_linewidth(4)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.xaxis.set_tick_params(width=5, length=10)
ax.yaxis.set_tick_params(width=5, length=10)
ax.tick_params(axis='x', labelsize=25)
ax.tick_params(axis='y', labelsize=25)
plt.title(cell, fontsize=25)
plt.ylabel(list(df_sim_plot["STAT_type"])[0], fontsize=25)
plt.xlabel('IL-10 (M)', fontsize=25)
plt.savefig('figures/raw_param/Plot_all_cell_variants_cutoff.png', transparent=True, bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Raw parameter values simulations of the 3 models

# %%
model_list = ["IL10","IL10_RAp","IL10_MS1"]
df_invit = pd.read_csv("data/signaling/IL10_STAT_data.tsv.gz", sep='\t', compression='gzip')
for model in model_list:
    df_sim = pd.read_csv("results/raw_param/simulations_raw_"+model+".csv")
    for plot_num in list(dict.fromkeys(df_sim["Plot"])):
        df_sim_plot = df_sim.loc[df_sim["Plot"]==plot_num]
        df_invit_plot = df_invit.loc[df_invit["Plot"]==plot_num]
    
        # First plot WT
        variant = "WT"
        variant_list = df_sim_plot["Variant"].drop_duplicates().to_list()
        variant_list.remove("WT")
        fig,ax=plt.subplots(1,1,figsize=(9, 8), dpi=400)
        max_WT = df_sim_plot.loc[df_sim_plot["Variant"]==variant]["Result"].max()
        ax.scatter(df_invit_plot.loc[df_invit_plot["Variant"]==variant]["IL"].values, df_invit_plot.loc[df_invit_plot["Variant"]==variant]["pSTAT"].values, s=200, linewidth=2, color="salmon",marker='*')
        ax.plot(df_sim_plot.loc[df_sim_plot["Variant"]==variant]["IL0"].values, np.multiply(df_sim_plot.loc[df_sim_plot["Variant"]==variant]["Result"].values,100/(max_WT)), linewidth=7.5, label=variant,color="darkred", linestyle="dashed")
        i=0
        # Then plot the other variants
        for variant in variant_list:
            ax.scatter(df_invit_plot.loc[df_invit_plot["Variant"]==variant]["IL"].values, df_invit_plot.loc[df_invit_plot["Variant"]==variant]["pSTAT"].values, s=200, linewidth=2, color=color_invit[i],marker=markers[i])
            ax.plot(df_sim_plot.loc[df_sim_plot["Variant"]==variant]["IL0"].values, np.multiply(df_sim_plot.loc[df_sim_plot["Variant"]==variant]["Result"].values,100/(max_WT)), linewidth=7.5, label=variant,color=color_sim[i], linestyle=linestyles[i])
            i += 1
        plt.legend(loc="upper left", fontsize=20)
        plt.xscale('log')
        ax.set_xticks(10**np.arange(round(np.log10(df_sim_plot["IL0"].min()),0)+1,round(np.log10(df_sim_plot["IL0"].max()),0)+1,2))
        ax.spines["bottom"].set_linewidth(4)
        ax.spines["left"].set_linewidth(4)
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)
        ax.xaxis.set_tick_params(width=5, length=10)
        ax.yaxis.set_tick_params(width=5, length=10)
        ax.tick_params(axis='x', labelsize=25)
        ax.tick_params(axis='y', labelsize=25)
        cell = df_sim_plot["Cell_type"].values[0]
        plt.title(cell, fontsize=25)
        plt.ylabel(list(df_sim_plot["STAT_type"])[0] +' (%)', fontsize=25)
        plt.xlabel('IL-10 (M)', fontsize=25)
        plt.savefig('figures/raw_param/'+model+'/Plot_n'+str(df_sim_plot["Plot"].values[0])+'_cell_'+df_sim_plot["Cell_type"].values[0]+'.png', transparent=True, bbox_inches="tight")
        plt.show()

# %% [markdown]
# ### Fitted parameter values with error on the Initial conditions

# %%
# Normalize in each plot for the maximum response of the WT IL-10
sim_data_list = ["simulations_fit_IL10_Control_eIC.csv","simulations_fit_IL10_RAp_eIC.csv","simulations_fit_IL10_RAp_eIC_ODE.csv"]
plots_folder_list = ["IL10","IL10_RAp","IL10_RAp_ODE"]

df_invit = pd.read_csv("data/signaling/IL10_STAT_data.tsv.gz", sep='\t', compression='gzip')

for sim_data_i in range(0,len(sim_data_list)):
    df_sim = pd.read_csv("results/fit_param/"+sim_data_list[sim_data_i])
    # Normalize data to the maximum WT response
    for plot_num in df_sim["Plot"].drop_duplicates():
        df_sim.loc[(df_sim["Plot"]==plot_num),"Result"] = df_sim.loc[(df_sim["Plot"]==plot_num),"Result"]/df_sim.loc[(df_sim["Plot"]==plot_num)&(df_sim["Variant"]=="WT"),"Result"].max()*100
    # Plot dose-response curves
    for plot_num in df_sim["Plot OG"].drop_duplicates():
        df_invit_plot = df_invit.loc[df_invit["Plot"]==plot_num]
    
        # First plot WT
        variant = "WT"
        variant_list = df_sim.loc[df_sim["Plot OG"]==plot_num,"Variant"].drop_duplicates().to_list()
        variant_list.remove("WT")
        fig,ax=plt.subplots(1,1,figsize=(9, 8), dpi=400)
        IL = df_sim.loc[(df_sim["Plot OG"]==plot_num),"IL0"].drop_duplicates().values
        responses = df_sim.loc[(df_sim["Plot OG"]==plot_num)&(df_sim["Variant"]==variant)][["Plot","IL0","Result"]].pivot(index='IL0', columns='Plot', values='Result').transpose().values
        original_response = responses[0]
        low_response = np.percentile(responses, 5, axis=0)
        high_response = np.percentile(responses, 95, axis=0)
    
        ax.fill_between(IL, low_response, high_response, color='indianred', alpha=0.5)
        ax.plot(IL, original_response, linewidth=7.5, label=variant,color="darkred", linestyle="dashed")
        ax.scatter(df_invit_plot.loc[df_invit_plot["Variant"]==variant]["IL"].values, df_invit_plot.loc[df_invit_plot["Variant"]==variant]["pSTAT"].values, s=200, linewidth=2, color="salmon",marker='*')
        
        i=0
        # Then plot the other variants
        for variant in variant_list:
            responses = df_sim.loc[(df_sim["Plot OG"]==plot_num)&(df_sim["Variant"]==variant)][["Plot","IL0","Result"]].pivot(index='IL0', columns='Plot', values='Result').transpose().values
            original_response = responses[0]
            low_response = np.percentile(responses, 5, axis=0)
            high_response = np.percentile(responses, 95, axis=0)
    
            ax.fill_between(IL, low_response, high_response, color=color_area[i], alpha=0.4)
            ax.plot(IL, original_response, linewidth=7.5, label=variant,color=color_sim[i], linestyle=linestyles[i])
            ax.scatter(df_invit_plot.loc[df_invit_plot["Variant"]==variant]["IL"].values, df_invit_plot.loc[df_invit_plot["Variant"]==variant]["pSTAT"].values, s=200, linewidth=2, color=color_invit[i],marker=markers[i])
            i += 1
        plt.legend(loc="upper left", fontsize=20)
        plt.xscale('log')
        ax.set_xticks(10**np.arange(round(np.log10(df_sim.loc[df_sim["Plot OG"]==plot_num,"IL0"].min()),0)+1,round(np.log10(df_sim.loc[df_sim["Plot OG"]==plot_num,"IL0"].max()),0)+1,2))
        ax.spines["bottom"].set_linewidth(4)
        ax.spines["left"].set_linewidth(4)
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)
        ax.xaxis.set_tick_params(width=5, length=10)
        ax.yaxis.set_tick_params(width=5, length=10)
        ax.tick_params(axis='x', labelsize=25)
        ax.tick_params(axis='y', labelsize=25)
        cell = df_sim.loc[df_sim["Plot OG"]==plot_num,"Cell_type"].values[0]
        plt.title(cell, fontsize=25)
        plt.ylabel(list(df_sim.loc[df_sim["Plot OG"]==plot_num,"STAT_type"])[0] +' (%)', fontsize=25)
        plt.xlabel('IL-10 (M)', fontsize=25)
        plt.savefig('figures/fit_param/'+plots_folder_list[sim_data_i]+'/Plot_n'+str(df_sim.loc[df_sim["Plot OG"]==plot_num,"Plot"].values[0])+'_cell_'+df_sim.loc[df_sim["Plot OG"]==plot_num,"Cell_type"].values[0]+'.png', transparent=True, bbox_inches="tight")
        plt.show()

# %% [markdown]
# ### Amplitude dose-response curves violin plots

# %%
# Get experimental data on response amplitude in the different cells
df_EC50_AMP = pd.concat([pd.read_csv('data/signaling/IL10_EC50_AMP.tsv.gz', sep="\t", compression="gzip"), pd.read_csv('data/signaling/IL10_EC50_AMP_CD8_Gorby.tsv.gz', sep="\t", compression="gzip")], ignore_index=True)
variants = ["WT","Super-10","R5A11D"]
df_EC50_AMP = df_EC50_AMP.loc[(df_EC50_AMP["Variant"].isin(variants))&(df_EC50_AMP["Plot"].isin([1,2,8,9,12,13,14,15]))]
df_EC50_AMP = df_EC50_AMP.loc[df_EC50_AMP["Variant"] != "WT"]
identifier = df_EC50_AMP["Cell_type"]+"__"+df_EC50_AMP["Variant"]+"__"+df_EC50_AMP["STAT_type"]
df_EC50_AMP = df_EC50_AMP[["Amp"]].transpose()
df_EC50_AMP.columns = identifier
df_EC50_AMP.columns = [col.replace("MO.Mean","Monocytes") for col in df_EC50_AMP.columns]
df_EC50_AMP.columns = [col.replace("T4.Mean","CD4+ T cells") for col in df_EC50_AMP.columns]
df_EC50_AMP.columns = [col.replace("T8.Mean","CD8+ T cells") for col in df_EC50_AMP.columns]
df_EC50_AMP = df_EC50_AMP[['Monocytes__R5A11D__pSTAT3','Monocytes__R5A11D__pSTAT1','CD8+ T cells__R5A11D__pSTAT3','CD8+ T cells__R5A11D__pSTAT1','CD4+ T cells__Super-10__pSTAT3','CD8+ T cells__Super-10__pSTAT3','CD8+ T cells__Super-10__pSTAT1','CD4+ T cells__Super-10__pSTAT1']]

# %%
model_list = ["IL10_Control","IL10_RAp","IL10_RAp_ODE"]
for model in model_list:
    # Get distribution of simulated amplitude in the different cells
    df_sim = pd.read_csv("results/fit_param/simulations_fit_"+model+"_eIC.csv")
    df_sim = df_sim.loc[df_sim["Plot OG"].isin([1,2,8,9,12,13,14,15])]
    for plot_num in df_sim["Plot"].drop_duplicates():
        df_sim.loc[(df_sim["Plot"]==plot_num),"Result"] = df_sim.loc[(df_sim["Plot"]==plot_num),"Result"]/df_sim.loc[(df_sim["Plot"]==plot_num)&(df_sim["Variant"]=="WT"),"Result"].max()*100
        df_amp = pd.DataFrame()
    for plot_num_OG in df_sim["Plot OG"].drop_duplicates():
        df_amp[df_sim.loc[(df_sim["Plot OG"]==plot_num_OG)&(df_sim["Variant"] != "WT")][["Cell_type","Variant","STAT_type"]].values[0][0]+"__"+df_sim.loc[(df_sim["Plot OG"]==plot_num_OG)&(df_sim["Variant"] != "WT")][["Cell_type","Variant","STAT_type"]].values[0][1]+"__"+df_sim.loc[(df_sim["Plot OG"]==plot_num_OG)&(df_sim["Variant"] != "WT")][["Cell_type","Variant","STAT_type"]].values[0][2]] = [df_sim.loc[(df_sim["Plot"]==plot_num)&(df_sim["Variant"] != "WT"),"Result"].max() for plot_num in df_sim.loc[(df_sim["Plot OG"]==plot_num_OG),"Plot"].drop_duplicates().values]
    df_amp.columns = [col.replace("MO.Mean","Monocytes") for col in df_amp.columns]
    df_amp.columns = [col.replace("T4.Mean","CD4+ T cells") for col in df_amp.columns]
    df_amp.columns = [col.replace("T8.Mean","CD8+ T cells") for col in df_amp.columns]
    df_amp = df_amp[['Monocytes__R5A11D__pSTAT3','Monocytes__R5A11D__pSTAT1','CD8+ T cells__R5A11D__pSTAT3','CD8+ T cells__R5A11D__pSTAT1','CD4+ T cells__Super-10__pSTAT3','CD8+ T cells__Super-10__pSTAT3','CD8+ T cells__Super-10__pSTAT1','CD4+ T cells__Super-10__pSTAT1']]
    
    # pSTAT1 amplitude
    df_amp_S1 = df_amp[[col for col in df_amp.columns if "pSTAT1" in col]]
    df_amp_S1.columns = [col.replace("__pSTAT1","").replace("__"," \n") for col in df_amp_S1.columns]
    df_EC50_AMP_S1 = df_EC50_AMP[[col for col in df_EC50_AMP.columns if "pSTAT1" in col]]
    df_EC50_AMP_S1.columns = [col.replace("__pSTAT1","").replace("__"," \n") for col in df_EC50_AMP_S1.columns]
    # Set up the figure and colors
    sns.set_palette("colorblind")
    fig, ax = plt.subplots(1, 1, figsize=(9, 8), dpi=400)
    sns.violinplot(data=df_amp_S1, cut=0, bw=0.5, ax=ax)
    sns.stripplot(data=df_EC50_AMP_S1,color='black',size=18,marker='^')
    
    # Customize appearance
    ax.spines["bottom"].set_linewidth(4)
    ax.spines["left"].set_linewidth(4)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.yaxis.set_tick_params(width=5, length=10)
    ax.xaxis.set_tick_params(width=5, length=10)
    ax.tick_params(axis='x', labelsize=18)
    ax.tick_params(axis='y', labelsize=18)
    plt.ylabel("pSTAT1 (%)", fontsize=18)
    plt.savefig('figures/fit_param/'+model+'_pSTAT1.png', transparent=True, bbox_inches="tight")
    
    # pSTAT3 amplitude
    df_amp_S3 = df_amp[[col for col in df_amp.columns if "pSTAT3" in col]]
    df_amp_S3.columns = [col.replace("__pSTAT3","").replace("__"," \n") for col in df_amp_S3.columns]
    df_EC50_AMP_S3 = df_EC50_AMP[[col for col in df_EC50_AMP.columns if "pSTAT3" in col]]
    df_EC50_AMP_S3.columns = [col.replace("__pSTAT3","").replace("__"," \n") for col in df_EC50_AMP_S3.columns]
    
    # Set up the figure and colors
    sns.set_palette("colorblind")
    fig, ax = plt.subplots(1, 1, figsize=(9, 8), dpi=400)
    sns.violinplot(data=df_amp_S3, cut=0, bw=0.5, ax=ax)
    sns.stripplot(data=df_EC50_AMP_S3,color='black',size=18,marker='^')
    
    # Customize appearance
    ax.spines["bottom"].set_linewidth(4)
    ax.spines["left"].set_linewidth(4)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)
    ax.yaxis.set_tick_params(width=5, length=10)
    ax.xaxis.set_tick_params(width=5, length=10)
    ax.tick_params(axis='x', labelsize=18)
    ax.tick_params(axis='y', labelsize=18)
    plt.ylabel("pSTAT3 (%)", fontsize=18)
    plt.savefig('figures/fit_param/'+model+'_pSTAT3.png', transparent=True, bbox_inches="tight")

# %%
# Get distribution of simulated amplitude in the different cells
df_sim = pd.read_csv("results/fit_param/simulations_fit_IL10_RAp_ODE_eIC.csv")
df_sim = df_sim.loc[df_sim["Plot OG"].isin([1,2,8,9,12,13,14,15])]
for plot_num in df_sim["Plot"].drop_duplicates():
    df_sim.loc[(df_sim["Plot"]==plot_num),"Result"] = df_sim.loc[(df_sim["Plot"]==plot_num),"Result"]/df_sim.loc[(df_sim["Plot"]==plot_num)&(df_sim["Variant"]=="WT"),"Result"].max()*100
    df_amp = pd.DataFrame()
for plot_num_OG in df_sim["Plot OG"].drop_duplicates():
    df_amp[df_sim.loc[(df_sim["Plot OG"]==plot_num_OG)&(df_sim["Variant"] != "WT")][["Cell_type","Variant","STAT_type"]].values[0][0]+"__"+df_sim.loc[(df_sim["Plot OG"]==plot_num_OG)&(df_sim["Variant"] != "WT")][["Cell_type","Variant","STAT_type"]].values[0][1]+"__"+df_sim.loc[(df_sim["Plot OG"]==plot_num_OG)&(df_sim["Variant"] != "WT")][["Cell_type","Variant","STAT_type"]].values[0][2]] = [df_sim.loc[(df_sim["Plot"]==plot_num)&(df_sim["Variant"] != "WT"),"Result"].max() for plot_num in df_sim.loc[(df_sim["Plot OG"]==plot_num_OG),"Plot"].drop_duplicates().values]
df_amp.columns = [col.replace("MO.Mean","Monocytes") for col in df_amp.columns]
df_amp.columns = [col.replace("T4.Mean","CD4+ T cells") for col in df_amp.columns]
df_amp.columns = [col.replace("T8.Mean","CD8+ T cells") for col in df_amp.columns]
df_amp = df_amp[['Monocytes__R5A11D__pSTAT3','Monocytes__R5A11D__pSTAT1','CD8+ T cells__R5A11D__pSTAT3','CD8+ T cells__R5A11D__pSTAT1','CD4+ T cells__Super-10__pSTAT3','CD8+ T cells__Super-10__pSTAT3','CD8+ T cells__Super-10__pSTAT1','CD4+ T cells__Super-10__pSTAT1']]

# pSTAT1 amplitude
df_amp_S1 = df_amp[[col for col in df_amp.columns if "pSTAT1" in col]]
df_amp_S1.columns = [col.replace("__pSTAT1","").replace("__"," \n") for col in df_amp_S1.columns]
df_EC50_AMP_S1 = df_EC50_AMP[[col for col in df_EC50_AMP.columns if "pSTAT1" in col]]
df_EC50_AMP_S1.columns = [col.replace("__pSTAT1","").replace("__"," \n") for col in df_EC50_AMP_S1.columns]

# pSTAT3 amplitude
df_amp_S3 = df_amp[[col for col in df_amp.columns if "pSTAT3" in col]]
df_amp_S3.columns = [col.replace("__pSTAT3","").replace("__"," \n") for col in df_amp_S3.columns]
df_EC50_AMP_S3 = df_EC50_AMP[[col for col in df_EC50_AMP.columns if "pSTAT3" in col]]
df_EC50_AMP_S3.columns = [col.replace("__pSTAT3","").replace("__"," \n") for col in df_EC50_AMP_S3.columns]

# %%
ax.violinplot(df_amp_S1, positions=pos_base + offset,
              widths=0.3, showextrema=False)

# %%
fig, ax = plt.subplots(1, 1, figsize=(13, 8), dpi=400)
pos_base = np.arange(len(df_amp_S1)) 
offset = 0.2

# Blue on the right
ax.violinplot(df_amp_S1, positions=pos_base + offset,
              widths=0.3, showextrema=False)

# Red on the left
ax.violinplot(df_amp_S3, positions=pos_base - offset,
              widths=0.3, showextrema=False)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 6
#       3 offset = 0.2
#       5 # Blue on the right
# ----> 6 ax.violinplot(df_amp_S1, positions=pos_base + offset,
#       7               widths=0.3, showextrema=False)
#       9 # Red on the left
#      10 ax.violinplot(df_amp_S3, positions=pos_base - offset,
#      11               widths=0.3, showextrema=False)
#
# File ~/miniconda3/envs/env_IL_models/lib/python3.10/site-packages/matplotlib/__init__.py:1442, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1439 @functools.wraps(func)
#    1440 def inner(ax, *args, data=None, **kwargs):
#    1441     if data is None:
# -> 1442         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1444     bound = new_sig.bind(ax, *args, **kwargs)
#    1445     auto_label = (bound.arguments.get(label_namer)
#    1446                   or bound.kwargs.get(label_namer))
#
# File ~/miniconda3/envs/env_IL_models/lib/python3.10/site-packages/matplotlib/axes/_axes.py:8089, in Axes.violinplot(self, dataset, positions, vert, widths, showmeans, showextrema, showmedians, quantiles, points, bw_method)
#    8085     return kde.evaluate(coords)
#    8087 vpstats = cbook.violin_stats(dataset, _kde_method, points=points,
#    8088                              quantiles=quantiles)
# -> 8089 return self.violin(vpstats, positions=positions, vert=vert,
#    8090                    widths=widths, showmeans=showmeans,
#    8091                    showextrema=showextrema, showmedians=showmedians)
#
# File ~/miniconda3/envs/env_IL_models/lib/python3.10/site-packages/matplotlib/axes/_axes.py:8199, in Axes.violin(self, vpstats, positions, vert, widths, showmeans, showextrema, showmedians)
#    8197     positions = range(1, N + 1)
#    8198 elif len(positions) != N:
# -> 8199     raise ValueError(datashape_message.format("positions"))
#    8201 # Validate widths
#    8202 if np.isscalar(widths):
#
# ValueError: List of violinplot statistics and `positions` values must have the same length

# %%
# Set up the figure and colors
sns.set_palette("colorblind")
fig, ax = plt.subplots(1, 1, figsize=(13, 8), dpi=400)
sns.violinplot(data=df_amp_S1, cut=0, bw=0.5, ax=ax, color="Darkblue")
sns.stripplot(data=df_EC50_AMP_S1,color='black',size=18,marker='^')

# Set up the figure and colors
sns.set_palette("colorblind")
sns.violinplot(data=df_amp_S3, cut=0, bw=0.5, ax=ax, color="Darkred",positions=[1.5,2.5,3.5,4.5])
sns.stripplot(data=df_EC50_AMP_S3,color='black',size=18,marker='^')

# Customize appearance
ax.spines["bottom"].set_linewidth(4)
ax.spines["left"].set_linewidth(4)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.yaxis.set_tick_params(width=5, length=10)
ax.xaxis.set_tick_params(width=5, length=10)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.ylabel("pSTAT (%)", fontsize=18)

# plt.savefig("figures/fit_param/IL10_RAp_ODE_Combined.png", transparent=True)
# plt.close(fig)
# Out:
# Text(0, 0.5, 'pSTAT (%)')

# %%
df_sim = pd.read_csv("results/fit_param/simulations_fit_IL10_RAp_ODE_eIC.csv")
df_sim = df_sim.loc[df_sim["Plot OG"].isin([1,2,8,9,12,13,14,15])]
for plot_num in df_sim["Plot"].drop_duplicates():
    df_sim.loc[(df_sim["Plot"]==plot_num),"Result"] = df_sim.loc[(df_sim["Plot"]==plot_num),"Result"]/df_sim.loc[(df_sim["Plot"]==plot_num)&(df_sim["Variant"]=="WT"),"Result"].max()*100
    df_amp = pd.DataFrame()
for plot_num_OG in df_sim["Plot OG"].drop_duplicates():
    df_amp[df_sim.loc[(df_sim["Plot OG"]==plot_num_OG)&(df_sim["Variant"] != "WT")][["Cell_type","Variant","STAT_type"]].values[0][0]+"__"+df_sim.loc[(df_sim["Plot OG"]==plot_num_OG)&(df_sim["Variant"] != "WT")][["Cell_type","Variant","STAT_type"]].values[0][1]+"__"+df_sim.loc[(df_sim["Plot OG"]==plot_num_OG)&(df_sim["Variant"] != "WT")][["Cell_type","Variant","STAT_type"]].values[0][2]] = [df_sim.loc[(df_sim["Plot"]==plot_num)&(df_sim["Variant"] != "WT"),"Result"].max() for plot_num in df_sim.loc[(df_sim["Plot OG"]==plot_num_OG),"Plot"].drop_duplicates().values]
df_amp.columns = [col.replace("MO.Mean","Monocytes") for col in df_amp.columns]
df_amp.columns = [col.replace("T4.Mean","CD4+ T cells") for col in df_amp.columns]
df_amp.columns = [col.replace("T8.Mean","CD8+ T cells") for col in df_amp.columns]
df_amp = df_amp[['Monocytes__R5A11D__pSTAT3','Monocytes__R5A11D__pSTAT1','CD8+ T cells__R5A11D__pSTAT3','CD8+ T cells__R5A11D__pSTAT1','CD4+ T cells__Super-10__pSTAT3','CD8+ T cells__Super-10__pSTAT3','CD8+ T cells__Super-10__pSTAT1','CD4+ T cells__Super-10__pSTAT1']]
# pSTAT1 amplitude
df_amp_S1 = df_amp[[col for col in df_amp.columns if "pSTAT1" in col]]
df_amp_S1.columns = [col.replace("__pSTAT1","").replace("__"," \n") for col in df_amp_S1.columns]
df_EC50_AMP_S1 = df_EC50_AMP[[col for col in df_EC50_AMP.columns if "pSTAT1" in col]]
df_EC50_AMP_S1.columns = [col.replace("__pSTAT1","").replace("__"," \n") for col in df_EC50_AMP_S1.columns]
# pSTAT3 amplitude
df_amp_S3 = df_amp[[col for col in df_amp.columns if "pSTAT3" in col]]
df_amp_S3.columns = [col.replace("__pSTAT3","").replace("__"," \n") for col in df_amp_S3.columns]
df_EC50_AMP_S3 = df_EC50_AMP[[col for col in df_EC50_AMP.columns if "pSTAT3" in col]]
df_EC50_AMP_S3.columns = [col.replace("__pSTAT3","").replace("__"," \n") for col in df_EC50_AMP_S3.columns]

# %% [markdown]
# ### Test dataset (single chain IL-10)

# %%
# Get data from simulations
df_sim = pd.read_csv("results/fit_param/simulations_fit_IL10_RAp_ODE_scIL10.csv")
df_EC50_sim = df_sim[["Plot","Cell_type","Variant","Plot OG"]].drop_duplicates().reset_index(drop=True)
EC50_list = []
for plot_num,cell_type,variant in [df_EC50_sim.loc[i].values[:-1] for i in range(0,len(df_EC50_sim))]:
    df_var = df_sim.loc[(df_sim["Plot"]==plot_num)&(df_sim["Cell_type"]==cell_type)&(df_sim["Variant"]==variant)]
    if variant == "WT":
        max_WT = df_var["Result"].max()
    fit, cov = curve_fit(hill_func, df_var["IL0"], df_var["Result"].values*100/(max_WT), bounds = ([0,df_var["IL0"].min()/10], [df_var["Result"].max()*100/(max_WT)+15, df_var["IL0"].max()*10]))
    EC50_list.append(np.log10(fit[1]))
df_EC50_sim["EC50"] = EC50_list
df_EC50_sim["Cell_Variant"] = df_EC50_sim["Cell_type"] + "\n" + df_EC50_sim["Variant"]
df_EC50_sim["Marker"] = (df_EC50_sim["Plot"]-df_EC50_sim["Plot OG"])/2
df_EC50_sim = df_EC50_sim.pivot(index='Marker', columns='Cell_Variant', values='EC50').reset_index(drop=True)
df_EC50_sim.columns = df_EC50_sim.columns.values

df_EC50_AMP_train = pd.read_csv('data/signaling/IL10sc_EC50_AMP_Montero.tsv.gz', sep="\t", compression="gzip")
df_EC50_AMP_train["Plot__Variant"] = df_EC50_AMP_train["Plot"].astype(str)+"__"+df_EC50_AMP_train["Variant"]
df_EC50_AMP_train.index = df_EC50_AMP_train["Cell_type"] + "\n" + df_EC50_AMP_train["Variant"]
df_EC50_AMP_train = df_EC50_AMP_train[["EC50"]].transpose().reset_index(drop=True)
df_EC50_AMP_train = df_EC50_AMP_train[df_EC50_sim.columns]

# Set up the figure and colors
sns.set_palette("colorblind")
fig, ax = plt.subplots(1, 1, figsize=(9, 8), dpi=400)
sns.violinplot(data=df_EC50_sim, cut=0, bw=0.5, ax=ax)
sns.stripplot(data=df_EC50_AMP_train,color='black',size=18,marker='^')

# Customize appearance
ax.spines["bottom"].set_linewidth(4)
ax.spines["left"].set_linewidth(4)
ax.spines["top"].set_visible(False)
ax.spines["right"].set_visible(False)
ax.yaxis.set_tick_params(width=5, length=10)
ax.xaxis.set_tick_params(width=5, length=10)
ax.tick_params(axis='x', labelsize=18)
ax.tick_params(axis='y', labelsize=18)
plt.ylabel("EC50 (M)", fontsize=18)
plt.savefig('figures/fit_param/IL10_RAp_scIL10.png', transparent=True, bbox_inches="tight")

print("MAE WT and MutSC1 in BLaER1 and Haftl cell lines: "+str((df_EC50_sim-df_EC50_AMP_train.values).abs().melt()["value"].mean()))

# %% [markdown]
# ### Test dataset (monomeric IL-10)

# %%
# Normalize in each plot for the maximum response of the WT IL-10
df_invit = pd.read_csv("data/signaling/IL10M_STAT_data_Gorby.tsv.gz", sep='\t', compression='gzip')
sim_data_list = ["simulations_fit_IL10_RAp_ODE_MONO_eIC.csv","simulations_fit_IL10_RAp_ODE_MONO_fit_eIC.csv"]
plots_folder_list = ["IL10_RAp_ODE_MONO","IL10_RAp_ODE_MONO/retrained"]

for sim_data_i in range(0,len(sim_data_list)):
    df_sim = pd.read_csv("results/fit_param/"+sim_data_list[sim_data_i])
    # Normalize data to the maximum WT response
    for plot_num in df_sim["Plot"].drop_duplicates():
        df_sim.loc[(df_sim["Plot"]==plot_num),"Result"] = df_sim.loc[(df_sim["Plot"]==plot_num),"Result"]/df_sim.loc[(df_sim["Plot"]==plot_num)&(df_sim["Variant"]=="WT"),"Result"].max()*100

    # For each plot get mean response and the 90% confidence intervals
    for plot_num in df_sim["Plot OG"].drop_duplicates():
        df_invit_plot = df_invit.loc[df_invit["Plot"]==plot_num]
    
        # First plot WT
        variant = "WT"
        variant_list = df_sim.loc[df_sim["Plot OG"]==plot_num,"Variant"].drop_duplicates().to_list()
        variant_list.remove("WT")
        fig,ax=plt.subplots(1,1,figsize=(9, 8), dpi=400)
        IL = df_sim.loc[(df_sim["Plot OG"]==plot_num),"IL0"].drop_duplicates().values
        responses = df_sim.loc[(df_sim["Plot OG"]==plot_num)&(df_sim["Variant"]==variant)][["Plot","IL0","Result"]].pivot(index='IL0', columns='Plot', values='Result').transpose().values
        original_response = responses[0]
        low_response = np.percentile(responses, 5, axis=0)
        high_response = np.percentile(responses, 95, axis=0)
    
        ax.fill_between(IL, low_response, high_response, color='indianred', alpha=0.5)
        ax.plot(IL, original_response, linewidth=7.5, label=variant,color="darkred", linestyle="dashed")
        ax.scatter(df_invit_plot.loc[df_invit_plot["Variant"]==variant]["IL"].values, df_invit_plot.loc[df_invit_plot["Variant"]==variant]["pSTAT"].values, s=200, linewidth=2, color="salmon",marker='*')
        
        i=0
        # Then plot the other variants
        for variant in variant_list:
            responses = df_sim.loc[(df_sim["Plot OG"]==plot_num)&(df_sim["Variant"]==variant)][["Plot","IL0","Result"]].pivot(index='IL0', columns='Plot', values='Result').transpose().values
            original_response = responses[0]
            low_response = np.percentile(responses, 5, axis=0)
            high_response = np.percentile(responses, 95, axis=0)
    
            ax.fill_between(IL, low_response, high_response, color=color_area[i], alpha=0.4)
            ax.plot(IL, original_response, linewidth=7.5, label=variant,color=color_sim[i], linestyle=linestyles[i])
            ax.scatter(df_invit_plot.loc[df_invit_plot["Variant"]==variant]["IL"].values, df_invit_plot.loc[df_invit_plot["Variant"]==variant]["pSTAT"].values, s=200, linewidth=2, color=color_invit[i],marker=markers[i])
            
            i += 1
        plt.legend(loc="upper left", fontsize=20)
        plt.xscale('log')
        ax.set_xticks(10**np.arange(round(np.log10(df_sim.loc[df_sim["Plot OG"]==plot_num,"IL0"].min()),0)+1,round(np.log10(df_sim.loc[df_sim["Plot OG"]==plot_num,"IL0"].max()),0)+1,2))
        ax.spines["bottom"].set_linewidth(4)
        ax.spines["left"].set_linewidth(4)
        ax.spines["top"].set_visible(False)
        ax.spines["right"].set_visible(False)
        ax.xaxis.set_tick_params(width=5, length=10)
        ax.yaxis.set_tick_params(width=5, length=10)
        ax.tick_params(axis='x', labelsize=25)
        ax.tick_params(axis='y', labelsize=25)
        cell = df_sim.loc[df_sim["Plot OG"]==plot_num,"Cell_type"].values[0]
        plt.title(cell, fontsize=25)
        plt.ylabel(list(df_sim.loc[df_sim["Plot OG"]==plot_num,"STAT_type"])[0] +' (%)', fontsize=25)
        plt.xlabel('IL-10 (M)', fontsize=25)
        plt.savefig('figures/fit_param/'+plots_folder_list[sim_data_i]+'/Plot_n'+str(df_sim.loc[df_sim["Plot OG"]==plot_num,"Plot"].values[0])+'_cell_'+df_sim.loc[df_sim["Plot OG"]==plot_num,"Cell_type"].values[0]+'.png', transparent=True, bbox_inches="tight")
        plt.show()

# %% [markdown]
# ### Get MAE in EC50 and amplitude on all models in training and test data

# %%
df_EC50_AMP = pd.read_csv('data/signaling/IL10_EC50_AMP.tsv.gz', sep="\t", compression="gzip")
# Get only data on certain variant and cells to fit
df_EC50_AMP_train = df_EC50_AMP.loc[(df_EC50_AMP["Variant"].isin(["WT","Super-10","R5A11D"]))&(df_EC50_AMP["Cell_type"].isin(["T8.Mean","T4.Mean","MO.Mean","ACH-000146","ACH-000786"]))]
df_EC50_AMP_train["Plot__Variant"] = df_EC50_AMP_train["Plot"].astype(str)+"__"+df_EC50_AMP_train["Variant"]
df_EC50_AMP_test = pd.concat([df_EC50_AMP.loc[(df_EC50_AMP["Variant"].isin(["WT","Super-10","R5A11D"]))&(~df_EC50_AMP["Cell_type"].isin(["T8.Mean","T4.Mean","MO.Mean","ACH-000146","ACH-000786"]))], pd.read_csv('data/signaling/IL10_EC50_AMP_CD8_Gorby.tsv.gz', sep="\t", compression="gzip")], ignore_index=True)
df_EC50_AMP_test["Plot__Variant"] = df_EC50_AMP_test["Plot"].astype(str)+"__"+df_EC50_AMP_test["Variant"]

# %%
model_list = ["Control","Control_ODE","RAp","RAp_ODE"]
print("Error in training set:")
for model in model_list:
    df_sim = pd.read_csv("results/fit_param/simulations_fit_IL10_"+model+".csv")
    plot_num_old = 0
    # For each celltype/variant simulated
    for key in df_EC50_AMP_train["Plot__Variant"]:
        plot_num, variant = key.split("__")
        plot_num = int(plot_num)
        df_var = df_sim.loc[(df_sim["Plot"] == plot_num)&(df_sim["Variant"] == variant)]
        # Data is normalized to the first variant that appears in a plot (Determined from df_sim to be WT)
        if plot_num_old != plot_num:
            max_WT = df_var["Result"].max()
            fit, cov = curve_fit(hill_func, df_var["IL0"], df_var["Result"].values*100/(max_WT), bounds = ([0,df_var["IL0"].min()/10], [100, df_var["IL0"].max()*10]))
            df_EC50_AMP_train.loc[df_EC50_AMP_train["Plot__Variant"]==key,"Amp_m"] = fit[0]
            df_EC50_AMP_train.loc[df_EC50_AMP_train["Plot__Variant"]==key,"EC50_m"] = np.log10(fit[1])
        else:
            fit, cov = curve_fit(hill_func, df_var["IL0"], df_var["Result"].values*100/(max_WT), bounds = ([0,df_var["IL0"].min()/10], [df_var["Result"].max()*100/(max_WT)+5, df_var["IL0"].max()*10]))
            df_EC50_AMP_train.loc[df_EC50_AMP_train["Plot__Variant"]==key,"Amp_m"] = fit[0]
            df_EC50_AMP_train.loc[df_EC50_AMP_train["Plot__Variant"]==key,"EC50_m"] = np.log10(fit[1])
        plot_num_old = plot_num
    print("Model analyzed: "+model)
    print("MAE_EC50: "+str((df_EC50_AMP_train["EC50"]-df_EC50_AMP_train["EC50_m"]).abs().mean()))
    print("MAE_Amp: "+str((df_EC50_AMP_train["Amp"]-df_EC50_AMP_train["Amp_m"]).abs().mean()))
# Out:
# Error in training set:
# Model analyzed: Control
# MAE_EC50: 0.4618950668750984
# MAE_Amp: 10.72139348450734
# Model analyzed: Control_ODE
# MAE_EC50: 0.46022565916329733
# MAE_Amp: 10.659518219148598
# Model analyzed: RAp
# MAE_EC50: 0.4713112539852901
# MAE_Amp: 6.7340219971416815
# Model analyzed: RAp_ODE
# MAE_EC50: 0.26802998586556875
# MAE_Amp: 4.951905779968767

# %%
model_list = ["Control","Control_ODE","RAp","RAp_ODE"]
print("Error in test set:")
for model in model_list:
    df_sim = pd.read_csv("results/fit_param/simulations_fit_IL10_"+model+".csv")
    plot_num_old = 0
    # For each celltype/variant simulated
    for key in df_EC50_AMP_test["Plot__Variant"]:
        plot_num, variant = key.split("__")
        plot_num = int(plot_num)
        df_var = df_sim.loc[(df_sim["Plot"] == plot_num)&(df_sim["Variant"] == variant)]
        # Data is normalized to the first variant that appears in a plot (Determined from df_sim to be WT)
        if plot_num_old != plot_num:
            max_WT = df_var["Result"].max()
            fit, cov = curve_fit(hill_func, df_var["IL0"], df_var["Result"].values*100/(max_WT), bounds = ([0,df_var["IL0"].min()/10], [100, df_var["IL0"].max()*10]))
            df_EC50_AMP_test.loc[df_EC50_AMP_test["Plot__Variant"]==key,"Amp_m"] = fit[0]
            df_EC50_AMP_test.loc[df_EC50_AMP_test["Plot__Variant"]==key,"EC50_m"] = np.log10(fit[1])
        else:
            fit, cov = curve_fit(hill_func, df_var["IL0"], df_var["Result"].values*100/(max_WT), bounds = ([0,df_var["IL0"].min()/10], [df_var["Result"].max()*100/(max_WT)+5, df_var["IL0"].max()*10]))
            df_EC50_AMP_test.loc[df_EC50_AMP_test["Plot__Variant"]==key,"Amp_m"] = fit[0]
            df_EC50_AMP_test.loc[df_EC50_AMP_test["Plot__Variant"]==key,"EC50_m"] = np.log10(fit[1])
        plot_num_old = plot_num
    print("Model analyzed: "+model)
    print("MAE_EC50: "+str((df_EC50_AMP_test["EC50"]-df_EC50_AMP_test["EC50_m"]).abs().mean()))
    print("MAE_Amp: "+str((df_EC50_AMP_test["Amp"]-df_EC50_AMP_test["Amp_m"]).abs().mean()))
# Out:
# Error in test set:
# Model analyzed: Control
# MAE_EC50: 0.3151200919619936
# MAE_Amp: 12.05469114011858
# Model analyzed: Control_ODE
# MAE_EC50: 0.2973696530698208
# MAE_Amp: 11.169640327701122
# Model analyzed: RAp
# MAE_EC50: 0.3318142241371909
# MAE_Amp: 8.16495805859785
# Model analyzed: RAp_ODE
# MAE_EC50: 0.24034842423757782
# MAE_Amp: 9.756490875528076
