# %%
import numpy as np
import pandas as pd
from scipy import optimize
from scipy.optimize import curve_fit
from multiprocessing import Pool
from itertools import combinations_with_replacement
import sympy as sp
from scipy.optimize import fsolve
import pyabc
import pyabc.sge
from scipy.interpolate import interp1d

# %%
def hill_func(inp,B,K):
    out=B*inp/(K+inp)
    return out

######################################################################################################################################################

def simulate_sequential(df_sim_data, model_func):
    for i in range(0,len(df_sim_data.index)):
        PA_res = model_func([df_sim_data.loc[[i]]])
        df_sim_data.loc[[i],"Result"] = PA_res["Result"].values[0]
    return df_sim_data

######################################################################################################################################################

def set_simulation_ABC_MS(df_bind, df_IC_data, df_EC50_AMP, num_IL_sim):
    cell__variant_list = []
    df_sim = pd.DataFrame(columns=["Plot","Cell_type","Variant","STAT_type"]+df_bind.columns.tolist()[1:]+["IL0","RA0","RB0","STAT10","STAT30","Result"])
    for plot_num in df_EC50_AMP["Plot"].drop_duplicates():
        df_plot_EC50 = df_EC50_AMP.loc[df_EC50_AMP["Plot"] == plot_num]
        RA0 = df_IC_data.loc[(df_IC_data["Cell"]==df_plot_EC50["Cell_type"].values[0])&(df_IC_data["Gene"]=="I10R1_HUMAN"),"Log10 Prot. count"].values[0]
        RB0 = df_IC_data.loc[(df_IC_data["Cell"]==df_plot_EC50["Cell_type"].values[0])&(df_IC_data["Gene"]=="I10R2_HUMAN"),"Log10 Prot. count"].values[0]
        STAT10 = df_IC_data.loc[(df_IC_data["Cell"]==df_plot_EC50["Cell_type"].values[0])&(df_IC_data["Gene"]=="STAT1_HUMAN"),"Log10 Prot. count"].values[0]
        STAT30 = df_IC_data.loc[(df_IC_data["Cell"]==df_plot_EC50["Cell_type"].values[0])&(df_IC_data["Gene"]=="STAT3_HUMAN"),"Log10 Prot. count"].values[0]
        if np.isnan(df_plot_EC50["EC50"].values[0]):
            IL_vec =  10**(np.linspace(df_EC50_AMP["EC50"].mean()-3, df_EC50_AMP["EC50"].mean()+2, num_IL_sim))
        else:
            IL_vec =  10**(np.linspace(df_plot_EC50["EC50"].mean()-3, df_plot_EC50["EC50"].mean()+2, num_IL_sim))
        variants_plot = list(df_plot_EC50["Variant"].drop_duplicates())
        variants_plot.remove("WT")
        variants_plot = ["WT"]+variants_plot
        for variant in variants_plot:
            cell__variant = df_plot_EC50["Cell_type"].values[0]+"__"+variant
            df_var_EC50 = df_plot_EC50.loc[df_plot_EC50["Variant"] == variant]
            for i in range(0,num_IL_sim):
                df_sim.loc[len(df_sim.index)] = df_var_EC50.loc[df_var_EC50.index[0]].tolist()[:-7] + df_bind.loc[df_bind["Variant"]==variant].values.flatten().tolist()[1:] + [IL_vec[i],RA0,RB0,STAT10,STAT30,np.nan]
    return df_sim

######################################################################################################################################################

# Update the dataset of the binding rates
def update_df_sim_bind_ABC_MS(df_sim, param_dict, param_depen, param_unique_var, variants_list):
    # Create copy of binding dataframe
    df_sim_fit = df_sim.copy()

    # Update df_bind with new parameter values
    for variant in variants_list:
        if variant == "WT":
            for param in [key.split('__')[1] for key in param_dict.keys() if key.split('__')[0] == variant]:
                # Copy new parameter to dataframe
                df_sim_fit.loc[df_sim_fit["Variant"] == variant,param] = 10**param_dict[variant+"__"+param]
                # Parameter dependancies
                if param in param_depen.keys():
                    for param_d in param_depen[param]:
                        param1_0 = df_sim_fit.loc[df_sim_fit["Variant"] == variant, param]
                        param2_0 = df_sim_fit.loc[df_sim_fit["Variant"] == variant, param_d]
                        df_sim_fit.loc[df_sim_fit["Variant"] == variant, param_d] = (10**param_dict[variant+"__"+param])/param1_0*param2_0
                # Parameter which are the same for WT and other variants must be also changed in the variant parameter row
                for variant_WT_mut in variants_list[1:]: # For all the non-WT variants
                    if param not in param_unique_var[variant_WT_mut]:
                        param_dep_bool = True # If parameter is not unique to the variant, then it must be changed following the WT
                        for param2 in param_unique_var[variant_WT_mut]:
                            if param2 in param_depen.keys(): 
                                if param == param_depen[param2]:
                                    param_dep_bool = False # If parameter is not unique to the variant, but is dependant to a unique one, then it must be changed following the variant parameter
                        # Change the variant non-unqiue parameter and the ones that depend on it, following the WT one
                        if param_dep_bool:
                            df_sim_fit.loc[df_sim_fit["Variant"] == variant_WT_mut, param] = 10**param_dict[variant+"__"+param]
                            # Parameter dependancies
                            if param in param_depen.keys():
                                for param_d in param_depen[param]:
                                    param1_0 = df_sim_fit.loc[df_sim_fit["Variant"] == variant, param]
                                    param2_0 = df_sim_fit.loc[df_sim_fit["Variant"] == variant, param_d]
                                    df_sim_fit.loc[df_sim_fit["Variant"] == variant_WT_mut, param_d] = (10**param_dict[variant+"__"+param])/param1_0*param2_0
        # If parameter is not specified as WT, then its unique to the variant -> change only parameter and the ones that depend on it
        else:
            for param in [key.split('__')[1] for key in param_dict.keys() if key.split('__')[0] == variant]:
                df_sim_fit.loc[df_sim_fit["Variant"] == variant, param] = 10**param_dict[variant+"__"+param]
                # Parameter dependancies
                if param in param_depen.keys():
                    for param_d in param_depen[param]:
                        param1_0 = df_sim_fit.loc[df_sim_fit["Variant"] == variant, param]
                        param2_0 = df_sim_fit.loc[df_sim_fit["Variant"] == variant, param_d]
                        df_sim_fit.loc[df_sim_fit["Variant"] == variant, param_d] = (10**param_dict[variant+"__"+param])/param1_0*param2_0
    return df_sim_fit

# %%
# Imports
import numpy as np
from src.models.IL10 import model_function as model_function_IL10
from src.models.IL10_RAp import model_function as model_function_IL10_RAp
from src.models.IL10_MS1 import model_function as model_function_IL10_MS1
import pandas as pd
from scipy.optimize import curve_fit
import pyabc
import pyabc.sge

# Initialize datasets
ABC_SMC_path = "/results/ABC_SMC"
path_data = '~/mounts/crg_hpc/PhD_code'
df_bind = pd.read_csv('data/binding/IL10_data_param.csv')
df_fit_data = pd.read_csv(path_data+'/IL10/data/ABC_SMC/param_inference_IC_IL10_proves.csv') # Parameters to fit
df_fit_data["Var__Param"] = df_fit_data["Variant"]+"__"+df_fit_data["Parameter"]
df_fit_data = df_fit_data[["Model","Var__Param","Initial_val","Lower_bound","Upper_bound"]]
df_sim_data = pd.read_csv(path_data+'/Data_analysis/data_IL2_mut/IL2_data.csv')
df_EC50_AMP = pd.read_csv('data/signaling/IL10_EC50_AMP.tsv.gz', sep="\t", compression="gzip")
df_IC_data = pd.read_csv('data/expression/whole_dataset_IL10.tsv.gz', sep="\t", compression="gzip")

# Get only data on certain variant
variants = ["WT","Super-10"]
df_sim_data = df_sim_data.loc[df_sim_data["Variant"].isin(variants)]
df_EC50_AMP = df_EC50_AMP.loc[df_EC50_AMP["Variant"].isin(variants)]
df_bind = df_bind.loc[df_bind["Variant"].isin(variants)]
for variant in variants:
    df_fit_data = df_fit_data.loc[df_fit_data["Var__Param"].str.contains(variant)]

# Cells to fit
cells = ["T8.Mean","MO.Mean"]
df_sim_data = df_sim_data.loc[df_sim_data["Cell_type"].isin(cells)]
df_EC50_AMP = df_EC50_AMP.loc[df_EC50_AMP["Cell_type"].isin(cells)]

# Reduce the weight of the initial conditions dataset to run faster simulations]
cells = df_EC50_AMP["Cell_type"].drop_duplicates().values
df_IC_data = df_IC_data.loc[df_IC_data["Cell"].isin(cells)]

# Parameters data
param_depen = {'k_IL_RB_f':['k_IL_RA_RB_f'],'k_IL_RB_b':['k_IL_RA_RB_b']}
param_unique_var = {"WT": df_bind.columns[1:],'R5A11D':['k_IL_RB_f','k_IL_RB_b','k_IL_RA_RB_f','k_IL_RA_RB_b'],'Super-10':['k_IL_RB_f','k_IL_RB_b','k_IL_RA_RB_f','k_IL_RA_RB_b'],'10-DE':['k_IL_RB_f','k_IL_RB_b','k_IL_RA_RB_f','k_IL_RA_RB_b']}

# Simulation and ABC-SMC variables
num_IL_sim = 8
num_cores_ABC_SMC = 1 #24
ABC_SMC_path = "/pyABC.db"
conf95_interval = 1.25 #1.5 is to much since a lot of the population is out of bounds -> algorithm can't decrease the epsilon
pop_size_init = 100 #500
pop_size_max = 100 #1000
E_cv = 0.225 # Use 0.25 as maximum if the simulations take too long. 0.15 -> 300 indiv, 0.2 -> 100 indiv
min_epsilon = 0.01
max_num_iter = 20 # Use 10 for variants where only one parameter needs to be infered
WT_norm = True
model_function_dict = {
    "Control": model_function_IL10,
    "IL10_RAp": model_function_IL10_RAp
}

# %%
df_EC50_AMP
# Out:
#     Plot Cell_type   Variant STAT_type      EC50         Amp  EC50_m  Amp_m  \
# 0      1   MO.Mean        WT    pSTAT3 -9.462286  100.000000     NaN    NaN
# 2      2   MO.Mean        WT    pSTAT1 -8.796171  100.000000     NaN    NaN
# 13     6   MO.Mean        WT    pSTAT3 -9.297771  100.000000     NaN    NaN
# 14     6   MO.Mean  Super-10    pSTAT3 -9.100083  102.845317     NaN    NaN
# 22     9   T8.Mean        WT    pSTAT3 -9.318553  100.000000     NaN    NaN
# 23     9   T8.Mean  Super-10    pSTAT3 -9.284480  104.637226     NaN    NaN
# 31    12   T8.Mean        WT    pSTAT1       NaN  100.297619     NaN    NaN
# 32    12   T8.Mean  Super-10    pSTAT1       NaN  146.130952     NaN    NaN
#
#     EC50_e  Amp_e  Error
# 0      NaN    NaN    NaN
# 2      NaN    NaN    NaN
# 13     NaN    NaN    NaN
# 14     NaN    NaN    NaN
# 22     NaN    NaN    NaN
# 23     NaN    NaN    NaN
# 31     NaN    NaN    NaN
# 32     NaN    NaN    NaN

# %%
df_sim.loc[df_sim["Plot"]==9]
# Out:
#     Plot Cell_type   Variant STAT_type        vol_EC     surf_cell  \
# 32     9   T8.Mean        WT    pSTAT3  1.000000e-10  1.400000e-08
# 33     9   T8.Mean        WT    pSTAT3  1.000000e-10  1.400000e-08
# 34     9   T8.Mean        WT    pSTAT3  1.000000e-10  1.400000e-08
# 35     9   T8.Mean        WT    pSTAT3  1.000000e-10  1.400000e-08
# 36     9   T8.Mean        WT    pSTAT3  1.000000e-10  1.400000e-08
# 37     9   T8.Mean        WT    pSTAT3  1.000000e-10  1.400000e-08
# 38     9   T8.Mean        WT    pSTAT3  1.000000e-10  1.400000e-08
# 39     9   T8.Mean        WT    pSTAT3  1.000000e-10  1.400000e-08
# 40     9   T8.Mean  Super-10    pSTAT3  1.000000e-10  1.400000e-08
# 41     9   T8.Mean  Super-10    pSTAT3  1.000000e-10  1.400000e-08
# 42     9   T8.Mean  Super-10    pSTAT3  1.000000e-10  1.400000e-08
# 43     9   T8.Mean  Super-10    pSTAT3  1.000000e-10  1.400000e-08
# 44     9   T8.Mean  Super-10    pSTAT3  1.000000e-10  1.400000e-08
# 45     9   T8.Mean  Super-10    pSTAT3  1.000000e-10  1.400000e-08
# 46     9   T8.Mean  Super-10    pSTAT3  1.000000e-10  1.400000e-08
# 47     9   T8.Mean  Super-10    pSTAT3  1.000000e-10  1.400000e-08
#
#         vol_cell  k_ILM_f  k_ILM_b  k_IL_RA_f  ...  k_PHOS  k_DEPHOS  \
# 32  3.000000e-12   697000   0.0434     445000  ...  0.0055      0.01
# 33  3.000000e-12   697000   0.0434     445000  ...  0.0055      0.01
# 34  3.000000e-12   697000   0.0434     445000  ...  0.0055      0.01
# 35  3.000000e-12   697000   0.0434     445000  ...  0.0055      0.01
# 36  3.000000e-12   697000   0.0434     445000  ...  0.0055      0.01
# 37  3.000000e-12   697000   0.0434     445000  ...  0.0055      0.01
# 38  3.000000e-12   697000   0.0434     445000  ...  0.0055      0.01
# 39  3.000000e-12   697000   0.0434     445000  ...  0.0055      0.01
# 40  3.000000e-12   697000   0.0434     445000  ...  0.0055      0.01
# 41  3.000000e-12   697000   0.0434     445000  ...  0.0055      0.01
# 42  3.000000e-12   697000   0.0434     445000  ...  0.0055      0.01
# 43  3.000000e-12   697000   0.0434     445000  ...  0.0055      0.01
# 44  3.000000e-12   697000   0.0434     445000  ...  0.0055      0.01
# 45  3.000000e-12   697000   0.0434     445000  ...  0.0055      0.01
# 46  3.000000e-12   697000   0.0434     445000  ...  0.0055      0.01
# 47  3.000000e-12   697000   0.0434     445000  ...  0.0055      0.01
#
#     k_DEPHOS_R             M0           IL0       RA0       RB0    STAT10  \
# 32        0.01  219650.770335  4.994400e-13  3.034714  2.806558  5.578292
# 33        0.01  219650.770335  2.586837e-12  3.034714  2.806558  5.578292
# 34        0.01  219650.770335  1.339846e-11  3.034714  2.806558  5.578292
# 35        0.01  219650.770335  6.939697e-11  3.034714  2.806558  5.578292
# 36        0.01  219650.770335  3.594398e-10  3.034714  2.806558  5.578292
# 37        0.01  219650.770335  1.861710e-09  3.034714  2.806558  5.578292
# 38        0.01  219650.770335  9.642678e-09  3.034714  2.806558  5.578292
# 39        0.01  219650.770335  4.994400e-08  3.034714  2.806558  5.578292
# 40        0.01  219650.770335  4.994400e-13  3.034714  2.806558  5.578292
# 41        0.01  219650.770335  2.586837e-12  3.034714  2.806558  5.578292
# 42        0.01  219650.770335  1.339846e-11  3.034714  2.806558  5.578292
# 43        0.01  219650.770335  6.939697e-11  3.034714  2.806558  5.578292
# 44        0.01  219650.770335  3.594398e-10  3.034714  2.806558  5.578292
# 45        0.01  219650.770335  1.861710e-09  3.034714  2.806558  5.578292
# 46        0.01  219650.770335  9.642678e-09  3.034714  2.806558  5.578292
# 47        0.01  219650.770335  4.994400e-08  3.034714  2.806558  5.578292
#
#       STAT30  Result
# 32  5.140099     NaN
# 33  5.140099     NaN
# 34  5.140099     NaN
# 35  5.140099     NaN
# 36  5.140099     NaN
# 37  5.140099     NaN
# 38  5.140099     NaN
# 39  5.140099     NaN
# 40  5.140099     NaN
# 41  5.140099     NaN
# 42  5.140099     NaN
# 43  5.140099     NaN
# 44  5.140099     NaN
# 45  5.140099     NaN
# 46  5.140099     NaN
# 47  5.140099     NaN
#
# [16 rows x 31 columns]

# %%
# From EC50_AMP_model and EC50_AMP_exp
def cost_ABC(EC50_AMPm, EC50_AMP0):
    # Get wighted sum of squares (Euclidian distance)    
    e_AMP = 0
    e_EC50 = 0
    for key in EC50_AMP0.keys():
        if not np.isnan(EC50_AMP0[key][0]) and not np.isnan(EC50_AMPm[key][0]):
            e_AMP += (EC50_AMP0[key][0] - EC50_AMPm[key][0])**2
        if not np.isnan(EC50_AMP0[key][1]) and not np.isnan(EC50_AMPm[key][1]):
            e_EC50 += (EC50_AMP0[key][1] - EC50_AMPm[key][1])**2
    e_AMP = e_AMP/w_AMP
    e_EC50 = e_EC50/w_EC50
    return e_AMP + e_EC50

 # Create the model's functions
def create_function(name, model_function):
    # Define the function dynamically. From parameter_dict, simulate the desired model for all cells/variants we need
    def dynamic_model(parameter_dict):
        # If sampled parameters are outside of the bounds do not simulate and output the simulation with original parameter values (high cost -> individual is not selected)
        if False in [(np.log10(df_fit_data.loc[df_fit_data["Var__Param"]==var__param,"Lower_bound"]).values[0] < parameter_dict[var__param]) & (np.log10(df_fit_data.loc[df_fit_data["Var__Param"]==var__param,"Upper_bound"]) > parameter_dict[var__param]).values[0] for var__param in parameter_dict.keys()]:
            EC50_AMP = EC50_AMP_prior.copy()
        
        # If the parameter values are inside the bounds simulate the model
        else:
            # Create new dataset of simulations with updated parameter values
            df_sim = update_df_sim_bind_ABC_MS(df_sim_copy, parameter_dict, param_depen, param_unique_var, variants_fit)
    
            # Simulate
            df_sim = simulate_sequential(df_sim, model_function)
            
            # Calculate EC50 and Amplitude error to add weight
            EC50_AMP = {key: [] for key in df_EC50_AMP["Plot"].astype(str)+"__"+df_EC50_AMP["Variant"] if key.split("__")[1] in variants_fit}
            
            plot_num_old = 0
            # For each celltype/variant simulated
            for key in EC50_AMP.keys():
                plot_num, variant = key.split("__")
                plot_num = int(plot_num)
                df_var = df_sim.loc[(df_sim["Plot"] == plot_num)&(df_sim["Variant"] == variant)]
                # Data is normalized to the first variant that appears in a plot
                if plot_num_old != plot_num:
                    max_WT = df_var["Result"].max()
                    fit, cov = curve_fit(hill_func, df_var["IL0"], df_var["Result"].values*100/(max_WT), bounds = ([0,df_var["IL0"].min()/10], [110, df_var["IL0"].max()*10]))
                    EC50_AMP[key].append(fit[0])
                    EC50_AMP[key].append(np.log10(fit[1]))
                else:
                    fit, cov = curve_fit(hill_func, df_var["IL0"], df_var["Result"].values*100/(max_WT), bounds = ([0,df_var["IL0"].min()/10], [df_var["Result"].max()*100/(max_WT)+10, df_var["IL0"].max()*10]))
                    EC50_AMP[key].append(fit[0])
                    EC50_AMP[key].append(np.log10(fit[1]))
                plot_num_old = plot_num
        return EC50_AMP

            plot_num_old = 0
            # For each celltype/variant simulated
            for key in EC50_AMP.keys():
                plot_num, variant = key.split("__")
                plot_num = int(plot_num)
                df_var = df_sim.loc[df_sim["Plot"] == plot_num].loc[df_sim.loc[df_sim["Plot"] == plot_num]["Variant"] == variant]
                # Data is normalized to the first variant that appears in a plot
                if plot_num_old != plot_num:
                    if WT_norm: # == True
                        max_WT = df_sim.loc[df_sim["Plot"] == plot_num].loc[df_sim.loc[df_sim["Plot"] == plot_num]["Variant"] == "WT"]["Result"].max()
                    else:
                        max_WT = df_var["Result"].max()
                    fit, cov = curve_fit(hill_func, df_var["IL0"], df_var["Result"].values*100/(max_WT), bounds = ([0,df_var["IL0"].min()/10], [110, df_var["IL0"].max()*10]))
                    EC50_AMP[key].append(fit[0])
                    EC50_AMP[key].append(np.log10(fit[1]))
                else:
                    fit, cov = curve_fit(hill_func, df_var["IL0"], df_var["Result"].values*100/(max_WT), bounds = ([0,df_var["IL0"].min()/10], [df_var["Result"].max()*100/(max_WT)+10, df_var["IL0"].max()*10]))
                    EC50_AMP[key].append(fit[0])
                    EC50_AMP[key].append(np.log10(fit[1]))
                plot_num_old = plot_num
        return EC50_AMP

    # Set the function name
    dynamic_model.__name__ = name

    return dynamic_model

# %%
def model(parameter_dict):
    # If sampled parameters are outside of the bounds do not simulate and output the simulation with original parameter values (high cost -> individual is not selected)
    if False in [(np.log10(df_fit_data.loc[df_fit_data["Var__Param"]==var__param,"Lower_bound"]).values[0] < parameter_dict[var__param]) & (np.log10(df_fit_data.loc[df_fit_data["Var__Param"]==var__param,"Upper_bound"]) > parameter_dict[var__param]).values[0] for var__param in parameter_dict.keys()]:
        EC50_AMP = EC50_AMP_prior.copy()
        
    # If the parameter values are inside the bounds simulate the model
    else:
        # Update df_bind
        df_bind_fit = update_df_bind_ABC(df_bind, parameter_dict, param_depen, param_unique_var, variants_fit)

        # Create dataset of simulations
        df_sim = set_simulation_ABC(df_bind_fit, df_sim_data, df_IC_data, df_EC50_AMP, num_IL_sim, variants_fit)

        # Simulate
        df_sim = simulate_sequential(df_sim, model_function)

        # Add missing simulation data on certain plots where the pair of cell__variant is found more than one time but it can be simualted only once
        for plot_num_copy in cell__variant_missing_in_plot.keys():
            for plot_num_paste in cell__variant_missing_in_plot[plot_num_copy]:
                df_copy = df_sim.loc[df_sim["Plot"]==plot_num_copy].loc[df_sim.loc[df_sim["Plot"]==plot_num_copy]["Variant"]=="WT"]
                df_copy['Plot'] = plot_num_paste
                df_sim = pd.concat([df_sim, df_copy], ignore_index=True)

        # Calculate EC50 and Amplitude error to add weight
        EC50_AMP = {key: [] for key in df_EC50_AMP["Plot"].astype(str)+"__"+df_EC50_AMP["Variant"] if key.split("__")[1] in variants_fit}
        
        plot_num_old = 0
        # For each celltype/variant simulated
        for key in EC50_AMP.keys():
            plot_num, variant = key.split("__")
            plot_num = int(plot_num)
            df_var = df_sim.loc[df_sim["Plot"] == plot_num].loc[df_sim.loc[df_sim["Plot"] == plot_num]["Variant"] == variant]
            # Data is normalized to the first variant that appears in a plot
            if plot_num_old != plot_num:
                if WT_norm: # == True
                    max_WT = df_sim.loc[df_sim["Plot"] == plot_num].loc[df_sim.loc[df_sim["Plot"] == plot_num]["Variant"] == "WT"]["Result"].max()
                else:
                    max_WT = df_var["Result"].max()
                fit, cov = curve_fit(hill_func, df_var["IL0"], df_var["Result"].values*100/(max_WT), bounds = ([0,df_var["IL0"].min()/10], [110, df_var["IL0"].max()*10]))
                EC50_AMP[key].append(fit[0])
                EC50_AMP[key].append(np.log10(fit[1]))
            else:
                fit, cov = curve_fit(hill_func, df_var["IL0"], df_var["Result"].values*100/(max_WT), bounds = ([0,df_var["IL0"].min()/10], [df_var["Result"].max()*100/(max_WT)+10, df_var["IL0"].max()*10]))
                EC50_AMP[key].append(fit[0])
                EC50_AMP[key].append(np.log10(fit[1]))
            plot_num_old = plot_num
    return EC50_AMP
